# %%
import pyarrow
import pandas as pd
import tarfile
import os.path

# %%
available_dates = ['2022-08-02', '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-06', '2022-08-07', '2022-08-08', '2022-08-09', '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14', '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22', '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-26', '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-10', '2022-09-11', '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16', '2022-09-17', '2022-09-18', '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-24', '2022-09-25', '2022-09-26', '2022-09-27', '2022-09-28', '2022-09-29', '2022-09-30', '2022-10-01', '2022-10-02', '2022-10-03', '2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07', '2022-10-08', '2022-10-09', '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04']

# %%
for date in available_dates:
    addr = '../khatkesh_' + date
    pd.read_csv(addr + '.csv').to_parquet(addr + '.parquet')

# %%
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

# %%
make_tarfile('khatkesh_hulk3.tar.gz', '../parquets3')

# %%
a = pd.read_parquet('../khatkesh_parquets/khatkesh_2022-08-02.parquet')

# %%
a
# Out:
#          4714445434  2886013   193      0   1130  37.51126480102539  \
# 0        4714515783  2886013    69   24.0    890          37.557491
# 1        4714552709  2886013   260   21.0    526          37.557381
# 2        4714450471  2886106   169   48.0    860          38.059376
# 3        4714522636  2886106     0  280.0    512          38.068848
# 4        4714448641  2886255  1229  108.0   2581          35.722317
# ...             ...      ...   ...    ...    ...                ...
# 2681288  4720551829  2781614    87   10.0    354          35.310436
# 2681289  4720522147  2781826   250  188.0   1076          35.753277
# 2681290  4720494060  2782060    62   56.0    365          36.259991
# 2681291  4720544474  2782060   183   40.0   1274          36.265766
# 2681292  4718990628  2782063   167   84.0  16712          35.710651
#
#          45.041690826416016    1659381802       1.0  8c2c1100378e9ff  ...  \
# 0                 45.081829  1.659383e+09  0.769231  8c2c11009c955ff  ...
# ...
